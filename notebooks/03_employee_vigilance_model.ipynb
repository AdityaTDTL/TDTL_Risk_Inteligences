# %% [markdown]
# # Employee Vigilance Model
# Scores override behaviour, after-hours activity, suspicious access and maker-checker violations.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))
from tdtl_risk_ai.models.risk_models import HybridRiskScorer

# %%
payload = {"override_count_30d": 9, "suspicious_activity_count_30d": 5, "after_hours_activity_count": 7, "repeated_customer_access_count": 12, "maker_checker_violation_count": 2}
HybridRiskScorer().score_employee(payload)
