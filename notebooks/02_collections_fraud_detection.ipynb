# %% [markdown]
# # Collections Fraud Detection
# Detects month-end collection spikes, undeclared source funding and agent-level risk.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))
from tdtl_risk_ai.models.risk_models import HybridRiskScorer

# %%
payload = {"month_end_flag": True, "collection_spike_ratio": 3.4, "undeclared_source": True, "repeated_source_count": 6, "gps_mismatch_km": 5.5, "agent_prior_risk": 72}
HybridRiskScorer().score_collection(payload)
