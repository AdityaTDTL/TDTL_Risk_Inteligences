# %% [markdown]
# # Agentic Investigation Summary and Rule Recommendations
# Generates case summaries and recommended rule changes for risk teams.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))
from tdtl_risk_ai.agents.investigation_agents import InvestigationSummaryAgent, RuleRecommendationAgent

# %%
case = {"customer_id":"CUST00015", "risk_score": 91, "reasons": ["Undeclared repayment source", "Shared funding account", "Month-end collection spike"]}
InvestigationSummaryAgent().summarize(case)

# %%
metrics = {"month_end_spike_ratio": 3.1, "shared_source_accounts": 5, "bureau_inquiries_7d": 4}
RuleRecommendationAgent().recommend(metrics)
