# %% [markdown]
# # Graph Collusion Analytics
# Builds customer-account-agent-branch relationship graph to identify shared funding accounts and suspicious clusters.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent / "src"))
from tdtl_risk_ai.models.graph_models import collusion_indicators

# %%
records = [
    {"customer_id":"C1","source_account":"ACC9001","agent_id":"A1","branch":"Pune"},
    {"customer_id":"C2","source_account":"ACC9001","agent_id":"A1","branch":"Pune"},
    {"customer_id":"C3","source_account":"ACC9001","agent_id":"A2","branch":"Pune"},
    {"customer_id":"C4","source_account":"ACC1234","agent_id":"A3","branch":"Mumbai"},
]
collusion_indicators(records)
